# %%
import json
import string
from IPython.display import JSON
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from wordcloud import WordCloud,STOPWORDS
import re
import os
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer , CountVectorizer
# Evaluate the model performance

# %% [markdown]
# # 1. Dataset Exploration and Cleaning

# %%
# Load the JSON data from the file
with open('products.json', 'r') as f:
    data = json.load(f)

print("Total dataset is " + str(len(data)))
# Out:
# Total dataset is 51646

# %%
# Convert the data to a JSONable dictionary or list
json_data = data[:100]

#Display the JSON data in a pretty-printed format
print(json.dumps(json_data, indent=4))
# Out:
# [
#     {
#         "sku": 43900,
#         "name": "Duracell - AAA Batteries (4-Pack)",
#         "type": "HardGood",
#         "price": 5.49,
#         "upc": "041333424019",
#         "category": [
#             {
#                 "id": "pcmcat312300050015",
#                 "name": "Connected Home & Housewares"
#             },
#             {
#                 "id": "pcmcat248700050021",
#                 "name": "Housewares"
#             },
#             {
#                 "id": "pcmcat303600050001",
#                 "name": "Household Batteries"
#             },
#             {
#                 "id": "abcat0208002",
#                 "name": "Alkaline Batteries"
#             }
#         ],
#         "shipping": 5.49,
#         "description": "Compatible with select electronic devices; AAA size; DURALOCK Power Preserve technology; 4-pack",
#         "manufacturer": "Duracell",
#         "model": "MN2400B4Z",
# ...

# %% [markdown]
# We are interested in only "name, description, category".
# <p>We need only 1 category per product.</p>
# <p>The category is arranged in order of increasing specificity, from the broadest to the most detailed. </p>

# %%
def get_dataframe(data):
    column_names = ['name', 'description', 'category']
    large_cats = ['Appliances', 'Cell Phones', 'Audio']
    names, descriptions, categories = [], [], []

    for product in data:
        names.append(product['name'])
        descriptions.append(product['description'])
        
        if len(product['category']) > 1:
            categories.append(product['category'][1]['name'])
        else:
            categories.append(product['category'][0]['name'])
  
    df = pd.DataFrame(list(zip(names, descriptions, categories)), columns=column_names)
    return df

df = get_dataframe(data)

# %% [markdown]
# Check how the data frame look like

# %%
cat = pd.DataFrame(df) 
cat.head(10)
# Out:
#                                                                                               name  \
# 0                                                                Duracell - AAA Batteries (4-Pack)
# 1                                                  Duracell - AA 1.5V CopperTop Batteries (4-Pack)
# 2                                                                 Duracell - AA Batteries (8-Pack)
# 3                                                            Energizer - MAX Batteries AA (4-Pack)
# 4                                                                  Duracell - C Batteries (4-Pack)
# 5                                                                  Duracell - D Batteries (4-Pack)
# 6                                                                 Duracell - 9V Batteries (2-Pack)
# 7                                            Directed Electronics - Viper Audio Glass Break Sensor
# ...

# %% [markdown]
# Count frequency of categories in dataset

# %%
category_counts = df['category'].value_counts()
category_counts = category_counts[category_counts >= 500]
df_cleaned = df[df['category'].isin(category_counts.index)]
plt.figure(figsize=(16, 6))

category_counts.plot(kind='bar')


plt.title('Category Frequency')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.show()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)


display(pd.DataFrame(category_counts))
# Out:
#                                       category
# Cell Phone Accessories                    6176
# Small Kitchen Appliances                  3708
# Pre-Owned Games                           3556
# Computer Accessories & Peripherals        2414
# Digital Camera Accessories                2201
# Car Installation Parts & Accessories      1491
# Ranges, Cooktops & Ovens                  1345
# Home Audio                                1334
# iPad & Tablet Accessories                 1117
# Headphones                                1116
# Office & School Supplies                  1115
# Heating, Cooling & Air Quality            1064
# TV Stands, Mounts & Furniture             1029
# Refrigerators                              970
# Housewares                                 954
# Sheet Music & DVDs                         842
# Bluetooth & Wireless Speakers              708
# TV & Home Theater Accessories              667
# Car Audio                                  625
# ...

# %%
df_cleaned.shape
# Out:
# (35701, 3)

# %%
df_cleaned.head()
# Out:
#                                               name  \
# 0                Duracell - AAA Batteries (4-Pack)
# 1  Duracell - AA 1.5V CopperTop Batteries (4-Pack)
# 2                 Duracell - AA Batteries (8-Pack)
# 3            Energizer - MAX Batteries AA (4-Pack)
# 4                  Duracell - C Batteries (4-Pack)
#
#                                                                                                         description  \
# 0                   Compatible with select electronic devices; AAA size; DURALOCK Power Preserve technology; 4-pack
# 1  Long-lasting energy; DURALOCK Power Preserve technology; for toys, clocks, radios, games, remotes, PDAs and more
# 2                    Compatible with select electronic devices; AA size; DURALOCK Power Preserve technology; 8-pack
# 3                                                             4-pack AA alkaline batteries; battery tester included
# ...

# %%
plt.figure(figsize=(25,25))
text = df_cleaned.description.values
cloud = WordCloud(stopwords=STOPWORDS,
                  background_color='black',
                  collocations=False,
                  width=2500,
                  height=1800
                  ).generate(" ".join(text))
plt.axis('off')
plt.title("Common words",fontsize=40)
plt.imshow(cloud)

# %%
# Utility function for data cleaning, natural language processing concepts



def clean_punc(sentence):
    translator = str.maketrans('', '', string.punctuation)
    cleaned_text = sentence.translate(translator)
    return cleaned_text

def keep_alpha(sentence):
    return re.sub(r'[^a-zA-Z\s]+', '', sentence)

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# set the path where you want to save the downloaded resources
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))
# download the necessary resources
nltk.download('stopwords', download_dir="nltk_data")
nltk.download('punkt', download_dir="nltk_data")

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = nltk.word_tokenize(text)
    filtered_text = [word for word in word_tokens if not word.lower() in stop_words]
    return ' '.join(filtered_text)



stemmer = SnowballStemmer("english")
def stemming(sentence):
    sentence = str(sentence)
    stemSentence = ""
    for word in sentence.split():
        stem = stemmer.stem(word)
        stemSentence += stem
        stemSentence += " "
    stemSentence = stemSentence.strip()
    return stemSentence
# Out:
# [nltk_data] Downloading package stopwords to nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Applying data cleaning on description to ignore irrelevant words

df_cleaned = df_cleaned.assign(information=lambda x: x['name'] + ' ' + x['description']).drop(['name', 'description'], axis=1)
df_cleaned.head(100)
# Out:
#                                  category  \
# 0                              Housewares
# 1                              Housewares
# 2                              Housewares
# 3                              Housewares
# 4                              Housewares
# 5                              Housewares
# 6                              Housewares
# 8                              Housewares
# 9    Car Installation Parts & Accessories
# 10   Car Installation Parts & Accessories
# 11   Car Installation Parts & Accessories
# 12   Car Installation Parts & Accessories
# 13   Car Installation Parts & Accessories
# 14   Car Installation Parts & Accessories
# 17   Car Installation Parts & Accessories
# 18   Car Installation Parts & Accessories
# 19   Car Installation Parts & Accessories
# 20   Car Installation Parts & Accessories
# 21   Car Installation Parts & Accessories
# 22   Car Installation Parts & Accessories
# 23   Car Installation Parts & Accessories
# ...

# %%
df_cleaned.loc[:, 'information'] = df_cleaned['information'].str.lower()
df_cleaned.loc[:, 'information'] = df_cleaned['information'].apply(keep_alpha)

# %%
# has_punctuation = df_cleaned['description'].str.contains('[^\w\s]', regex=True)

# # print only the rows that contain punctuation
# print(df_cleaned[has_punctuation].tail(100))

stop_words = set(stopwords.words('english'))

# Function to check if any stopword is present in the text
def has_stopwords(text):
    words = nltk.word_tokenize(text.lower())
    for word in words:
        if word in stop_words:
            return True
    return False

# Apply the function to the 'text' column to create a new boolean column 'has_stopwords'
df_cleaned['has_stopwords'] = df_cleaned['information'].apply(has_stopwords)

# Filter the dataframe to include only rows that have stopwords
df_with_stopwords = df_cleaned[df_cleaned['has_stopwords'] == True]
pd.set_option('display.max_colwidth', None)

# Print the resulting dataframe
df_with_stopwords.tail(100)
# Out:
#                                  category  \
# 51483                     Pre-Owned Games
# 51484                     Pre-Owned Games
# 51485                     Pre-Owned Games
# 51486                     Pre-Owned Games
# 51487                     Pre-Owned Games
# 51488                     Pre-Owned Games
# 51489                     Pre-Owned Games
# 51490                     Pre-Owned Games
# 51491                     Pre-Owned Games
# 51492                     Pre-Owned Games
# 51493                     Pre-Owned Games
# 51494                     Pre-Owned Games
# 51495                     Pre-Owned Games
# 51496              Cell Phone Accessories
# 51497                     Pre-Owned Games
# 51498                     Pre-Owned Games
# 51499                     Pre-Owned Games
# 51500                     Pre-Owned Games
# 51501                     Pre-Owned Games
# 51502                     Pre-Owned Games
# 51503                     Pre-Owned Games
# ...

# %%
df_cleaned.loc[:, 'information'] = df_cleaned['information'].apply(remove_stopwords)
df_cleaned.loc[:, 'information'] = df_cleaned['information'].apply(stemming)

# %%
df_cleaned.tail(100)
# Out:
#                                  category  \
# 51502                     Pre-Owned Games
# 51503                     Pre-Owned Games
# 51504                     Pre-Owned Games
# 51505                     Pre-Owned Games
# 51506                     Pre-Owned Games
# 51507                     Pre-Owned Games
# 51508                     Pre-Owned Games
# 51509                     Pre-Owned Games
# 51510                     Pre-Owned Games
# 51511                     Pre-Owned Games
# 51512                     Pre-Owned Games
# 51513                     Pre-Owned Games
# 51514                     Pre-Owned Games
# 51515                     Pre-Owned Games
# 51516                     Pre-Owned Games
# 51517                     Pre-Owned Games
# 51518                     Pre-Owned Games
# 51519                     Pre-Owned Games
# 51520                     Pre-Owned Games
# 51521                     Pre-Owned Games
# 51522                     Pre-Owned Games
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df_cleaned['information'], 
                                                    df_cleaned['category'], 
                                                    test_size=0.2, 
                                                    random_state=0, 
                                                    shuffle=True)

vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,2), norm='l2')

X_train_tf = vectorizer.fit_transform(X_train)
X_test_tf = vectorizer.transform(X_test)

naive_bayes_classifier = MultinomialNB()
naive_bayes_classifier.fit(X_train_tf, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = naive_bayes_classifier.predict(X_test_tf)



print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8862904355132334

# %%
#print(X_test_tf)

x_real = ['JBL - Tune 130NC True Wireless Noise Cancelling In-Ear Earbuds - Black']

x_real_tf = vectorizer.transform(x_real)


result = naive_bayes_classifier.predict(x_real_tf)
print(result)
# Out:
# ['Headphones']
